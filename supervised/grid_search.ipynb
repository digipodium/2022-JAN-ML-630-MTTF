# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/house_pricing.csv")
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        814 non-null    object
#  1   Type        814 non-null    object
#  2   Beds        814 non-null    int64
#  3   Baths       814 non-null    int64
#  4   SquareFeet  814 non-null    int64
#  5   Price       814 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 38.3+ KB
#          City         Type  Beds  Baths  SquareFeet      Price
# 0  SACRAMENTO  Residential     2      1         836  138159.85
# 1  SACRAMENTO  Residential     3      1        1167  167541.46

# %%
# Feature selection (X, y) & Split into xtrain,xtest,ytrain,ytest
X = df[['Beds','Baths','SquareFeet']]
y = df['Price']
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=.2, random_state=1)

# %%
print("Random Forest")
model2 = RandomForestRegressor()
model2.fit(xtrain,ytrain)
print("score:", model2.score(xtest,ytest) * 100)
pred = model2.predict(X)
print("mse:",mean_squared_error(y,pred))
print("mae:",mean_absolute_error(y,pred))
# Out:
# Random Forest
# score: 72.2000872758184
# mse: 853468338.947107
# mae: 15242.034697425517

# %%
forest_score = cross_val_score(model2,X,y,cv=6)
print(forest_score, f"average: {forest_score.mean():.2f}",f"std :{forest_score.std():.2f}")
# Out:
# [0.80800374 0.69295761 0.71921476 0.73268795 0.49499625 0.61987999] average: 0.68 std :0.10

# %% [markdown]
# grid search

# %%
# we are going to create a dictionary with all the parameer and their value options
RandomForestRegressor?

# %%
params = {
    'n_estimators' : list(range(100,501,200)),
    'criterion': ["squared_error", "absolute_error", "poisson"],
    'max_depth': list(range(5,51,25)),
}
params
# Out:
# {'n_estimators': [100, 300, 500],
#  'criterion': ['squared_error', 'absolute_error', 'poisson'],
#  'max_depth': [5, 30]}

# %%
grid = GridSearchCV(estimator=RandomForestRegressor(),param_grid=params,cv=3,n_jobs=-1,verbose=1)

# %%
grid.fit(X,y)
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [5, 30],
#                          'n_estimators': [100, 300, 500]},
#              verbose=1)

# %%
gf = pd.DataFrame(grid.cv_results_)

# %%
gf.sort_values(by='rank_test_score',inplace=True)
gf
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8        8.689362      0.956430         0.397502        0.082658
# 7        4.045128      0.086454         0.121934        0.004893
# 6        1.397044      0.065017         0.049309        0.005249
# 1        1.765599      0.107407         0.124352        0.005258
# 2        2.833396      0.014929         0.200746        0.002997
# 0        0.724251      0.015426         0.049640        0.007582
# 10      10.129194      0.629709         0.174901        0.016053
# 11      11.350387      1.156914         0.267639        0.023958
# 3        0.745074      0.022811         0.054303        0.003398
# 5        3.584260      0.070385         0.245220        0.003325
# 9        2.589905      0.087182         0.087469        0.019158
# 4        2.125393      0.026646         0.157649        0.015447
# 16       3.518584      0.130215         0.130050        0.005125
# 17       4.641388      0.436366         0.181471        0.025688
# 15       1.338394      0.086467         0.063714        0.014286
# 14       3.665922      0.083810         0.247104        0.056304
# 13       2.009547      0.284916         0.131776        0.050908
# 12       0.590993      0.076113         0.036646        0.011550
#
#    param_criterion param_max_depth param_n_estimators  \
# 8   absolute_error               5                500
# 7   absolute_error               5                300
# 6   absolute_error               5                100
# 1    squared_error               5                300
# 2    squared_error               5                500
# 0    squared_error               5                100
# 10  absolute_error              30                300
# 11  absolute_error              30                500
# 3    squared_error              30                100
# 5    squared_error              30                500
# 9   absolute_error              30                100
# 4    squared_error              30                300
# 16         poisson              30                300
# 17         poisson              30                500
# 15         poisson              30                100
# 14         poisson               5                500
# 13         poisson               5                300
# 12         poisson               5                100
#
#                                                params  split0_test_score  \
# 8   {'criterion': 'absolute_error', 'max_depth': 5...           0.823299
# 7   {'criterion': 'absolute_error', 'max_depth': 5...           0.823564
# 6   {'criterion': 'absolute_error', 'max_depth': 5...           0.822951
# 1   {'criterion': 'squared_error', 'max_depth': 5,...           0.803017
# 2   {'criterion': 'squared_error', 'max_depth': 5,...           0.799720
# 0   {'criterion': 'squared_error', 'max_depth': 5,...           0.798553
# 10  {'criterion': 'absolute_error', 'max_depth': 3...           0.771046
# 11  {'criterion': 'absolute_error', 'max_depth': 3...           0.768954
# 3   {'criterion': 'squared_error', 'max_depth': 30...           0.761890
# 5   {'criterion': 'squared_error', 'max_depth': 30...           0.757499
# 9   {'criterion': 'absolute_error', 'max_depth': 3...           0.762964
# 4   {'criterion': 'squared_error', 'max_depth': 30...           0.753907
# 16  {'criterion': 'poisson', 'max_depth': 30, 'n_e...           0.746891
# 17  {'criterion': 'poisson', 'max_depth': 30, 'n_e...           0.744151
# 15  {'criterion': 'poisson', 'max_depth': 30, 'n_e...           0.721913
# 14  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.352096
# 13  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.353381
# 12  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.336488
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 8            0.766252           0.616774         0.735441        0.087083
# 7            0.767830           0.612315         0.734570        0.089392
# 6            0.766717           0.613703         0.734457        0.088418
# 1            0.767456           0.615974         0.728816        0.081101
# 2            0.766281           0.618943         0.728315        0.078533
# 0            0.769067           0.609192         0.725604        0.083191
# 10           0.757191           0.580327         0.702855        0.086825
# 11           0.758401           0.576321         0.701225        0.088426
# 3            0.754497           0.585547         0.700645        0.081442
# 5            0.754625           0.581439         0.697854        0.082327
# 9            0.757021           0.568524         0.696170        0.090292
# 4            0.754771           0.577677         0.695452        0.083280
# 16           0.752138           0.569999         0.689676        0.084652
# 17           0.752850           0.570046         0.689015        0.084199
# 15           0.749284           0.568512         0.679903        0.079554
# 14           0.503530           0.163341         0.339656        0.139160
# 13           0.503372           0.156440         0.337731        0.142066
# 12           0.512669           0.160239         0.336465        0.143879
#
#     rank_test_score
# 8                 1
# 7                 2
# 6                 3
# 1                 4
# 2                 5
# 0                 6
# 10                7
# 11                8
# 3                 9
# 5                10
# 9                11
# 4                12
# 16               13
# 17               14
# 15               15
# 14               16
# 13               17
# 12               18

# %%
grid.best_estimator_
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=5, n_estimators=500)

# %%
from joblib import dump

# %%
dump(grid.best_estimator_,"house_pricing_model_73.pkl")
# Out:
# ['house_pricing_model_73.pkl']
